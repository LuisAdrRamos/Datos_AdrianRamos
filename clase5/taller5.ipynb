# %%
import pandas as pd
import numpy as np

# %%
movies_df = pd.read_csv("IMDB-Movie-Data.csv", index_col="Title")

# %%
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movies_df.tail()
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 126.0+ KB

# %%
movies_df.shape
# Out:
# (1000, 11)

# %%
temp_df = pd.concat([movies_df, movies_df])
temp_df.shape
# Out:
# (2000, 11)

# %%
temp_df = temp_df.drop_duplicates()
temp_df.shape
# Out:
# (1000, 11)

# %%
movies_df.isnull()
# Out:
#                           Rank  Genre  Description  Director  Actors   Year  \
# Title
# Guardians of the Galaxy  False  False        False     False   False  False
# Prometheus               False  False        False     False   False  False
# Split                    False  False        False     False   False  False
# Sing                     False  False        False     False   False  False
# Suicide Squad            False  False        False     False   False  False
# ...                        ...    ...          ...       ...     ...    ...
# Secret in Their Eyes     False  False        False     False   False  False
# Hostel: Part II          False  False        False     False   False  False
# Step Up 2: The Streets   False  False        False     False   False  False
# Search Party             False  False        False     False   False  False
# Nine Lives               False  False        False     False   False  False
#
# ...

# %%
movies_df.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
m2 = movies_df.dropna()

# %%
m2.isnull().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
revenue = movies_df["Revenue (Millions)"]

# %%
revenue_mean = revenue.mean()
revenue_mean
# Out:
# np.float64(82.95637614678898)

# %%
revenue.fillna(revenue_mean, inplace=True)

# %%
movies_df.isnull().sum()
# Out:
# Rank                   0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64

# %%
meta = movies_df["Metascore"]

# %%
meta_mean = meta.mean()
meta_mean
# Out:
# np.float64(58.98504273504273)

# %%
meta.fillna(meta_mean, inplace=True)

# %%
movies_df.isnull().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
movies_df["Genre"].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: Genre, dtype: object

# %%
movies_df["Genre"].value_counts().head(10)
# Out:
# Genre
# Action,Adventure,Sci-Fi       50
# Drama                         48
# Comedy,Drama,Romance          35
# Comedy                        32
# Drama,Romance                 31
# Animation,Adventure,Comedy    27
# Action,Adventure,Fantasy      27
# Comedy,Drama                  27
# Comedy,Romance                26
# Crime,Drama,Thriller          24
# Name: count, dtype: int64

# %%
movies_df["Genre"].value_counts().tail(10)
# Out:
# Genre
# Adventure,Biography          1
# Adventure,Biography,Crime    1
# Comedy,Drama,Musical         1
# Comedy,Family,Romance        1
# Biography,Drama,Family       1
# Drama,Fantasy,Musical        1
# Adventure,Family             1
# Adventure,Comedy,Fantasy     1
# Drama,Family,Music           1
# Comedy,Family,Fantasy        1
# Name: count, dtype: int64

# %%
movies_df[movies_df["Rating"] >= 8.6].head(3)
# Out:
#                  Rank                    Genre  \
# Title
# Interstellar       37   Adventure,Drama,Sci-Fi
# The Dark Knight    55       Action,Crime,Drama
# Inception          81  Action,Adventure,Sci-Fi
#
#                                                        Description  \
# Title
# Interstellar     A team of explorers travel through a wormhole ...
# The Dark Knight  When the menace known as the Joker wreaks havo...
# Inception        A thief, who steals corporate secrets through ...
#
#                           Director  \
# Title
# Interstellar     Christopher Nolan
# The Dark Knight  Christopher Nolan
# Inception        Christopher Nolan
#
#                                                             Actors  Year  \
# Title
# Interstellar     Matthew McConaughey, Anne Hathaway, Jessica Ch...  2014
# The Dark Knight  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# Inception        Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
#
# ...

# %%
movies_df[movies_df["Rating"] >= 8.6].tail(3)
# Out:
#                   Rank                    Genre  \
# Title
# Kimi no na wa       97  Animation,Drama,Fantasy
# Dangal             118   Action,Biography,Drama
# The Intouchables   250   Biography,Comedy,Drama
#
#                                                         Description  \
# Title
# Kimi no na wa     Two strangers find themselves linked in a biza...
# Dangal            Former wrestler Mahavir Singh Phogat and his t...
# The Intouchables  After he becomes a quadriplegic from a paragli...
#
#                          Director  \
# Title
# Kimi no na wa      Makoto Shinkai
# Dangal              Nitesh Tiwari
# The Intouchables  Olivier Nakache
#
#                                                              Actors  Year  \
# Title
# Kimi no na wa     Ryûnosuke Kamiki, Mone Kamishiraishi, Ryô Nari...  2016
# Dangal            Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh,...  2016
# The Intouchables  François Cluzet, Omar Sy, Anne Le Ny, Audrey F...  2011
#
# ...

# %%
movies_df[movies_df["Revenue (Millions)"] >= 17].head(3)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
#
#                                    Director  \
# Title
# Guardians of the Galaxy          James Gunn
# Prometheus                     Ridley Scott
# Split                    M. Night Shyamalan
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# ...

# %%
movies_df[movies_df["Revenue (Millions)"] <= 17].tail(3)
# Out:
#                       Rank                 Genre  \
# Title
# The Skin I Live In     980        Drama,Thriller
# Taare Zameen Par       992    Drama,Family,Music
# Take Me Home Tonight   993  Comedy,Drama,Romance
#
#                                                             Description  \
# Title
# The Skin I Live In    A brilliant plastic surgeon, haunted by past t...
# Taare Zameen Par      An eight-year-old boy is thought to be a lazy ...
# Take Me Home Tonight  Four years after graduation, an awkward high s...
#
#                              Director  \
# Title
# The Skin I Live In    Pedro Almodóvar
# Taare Zameen Par           Aamir Khan
# Take Me Home Tonight    Michael Dowse
#
#                                                                  Actors  Year  \
# Title
# The Skin I Live In    Antonio Banderas, Elena Anaya, Jan Cornet,Mari...  2011
# Taare Zameen Par      Darsheel Safary, Aamir Khan, Tanay Chheda, Sac...  2007
# ...

# %%
movies_df[(movies_df["Director"]=="Christopher Nolan") | (movies_df["Director"]=="Ridley Scott")].head()
# Out:
#                  Rank                     Genre  \
# Title
# Prometheus          2  Adventure,Mystery,Sci-Fi
# Interstellar       37    Adventure,Drama,Sci-Fi
# The Dark Knight    55        Action,Crime,Drama
# The Prestige       65      Drama,Mystery,Sci-Fi
# Inception          81   Action,Adventure,Sci-Fi
#
#                                                        Description  \
# Title
# Prometheus       Following clues to the origin of mankind, a te...
# Interstellar     A team of explorers travel through a wormhole ...
# The Dark Knight  When the menace known as the Joker wreaks havo...
# The Prestige     Two stage magicians engage in competitive one-...
# Inception        A thief, who steals corporate secrets through ...
#
#                           Director  \
# Title
# Prometheus            Ridley Scott
# Interstellar     Christopher Nolan
# The Dark Knight  Christopher Nolan
# The Prestige     Christopher Nolan
# Inception        Christopher Nolan
#
# ...

# %%
movies_df[((movies_df["Year"]>=2005)&(movies_df["Year"]<=2010))&(movies_df["Rating"]>8.0)]
# Out:
#                           Rank                       Genre  \
# Title
# The Dark Knight             55          Action,Crime,Drama
# The Prestige                65        Drama,Mystery,Sci-Fi
# Inglourious Basterds        78         Adventure,Drama,War
# Inception                   81     Action,Adventure,Sci-Fi
# The Departed               100        Crime,Drama,Thriller
# No Country for Old Men     137        Crime,Drama,Thriller
# Shutter Island             139            Mystery,Thriller
# Into the Wild              198   Adventure,Biography,Drama
# Pan's Labyrinth            231           Drama,Fantasy,War
# There Will Be Blood        300               Drama,History
# The Bourne Ultimatum       428     Action,Mystery,Thriller
# 3 Idiots                   431                Comedy,Drama
# The Lives of Others        477              Drama,Thriller
# Up                         500  Animation,Adventure,Comedy
# WALL·E                     635  Animation,Adventure,Family
# ...

# %%
def rating_funcion(x):
    if x >= 8.0:
        return "MOTY (Movie of the year)"
    elif  x >= 7.0:
        return "Good"
    elif x >= 6.0:
        return "Normal"
    else:
        return "Bad"

# %%
movies_df["rating_category"] = movies_df["Rating"].apply(rating_funcion)

# %%
movies_df.head(10)
# Out:
#                          Rank                       Genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
def recaudacion(x):
    if x >= 20:
        return "Exito Total"
    elif x >= 10:
        return "Exito Parcial"
    else:
        return "Fracaso Total"

# %%
movies_df["revenue"] = movies_df["Revenue (Millions)"].apply(recaudacion)

# %%
movies_df.head(10)
# Out:
#                          Rank                       Genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
peliculas_db = pd.read_csv("peliculas_actualizadas.csv", index_col="Title")

# %%
peliculas_db
# Out:
#                                                IMDb Rating  Year Certificates  \
# Title
# Gladiator                                              8.5  2000            R
# Mission: Impossible - Dead Reckoning Part One          7.7  2023        PG-13
# Rebel Moon - Part Two: The Scargiver                   5.2  2024        PG-13
# Inglourious Basterds                                   8.4  2009            R
# Borderlands                                            7.1  2024            R
# ...                                                    ...   ...          ...
# Mother of the Bride                                    4.8  2024        TV-PG
# Beetlejuice Beetlejuice                                7.1  2024            R
# The Idea of You                                        6.4  2024            R
# IF                                                     6.7  2024           PG
# The Fall Guy                                           7.1  2024        PG-13
#
# ...

# %%
peliculas = peliculas_db.drop_duplicates()

# %%
peliculas_db.isnull().sum()
# Out:
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
peliculas[peliculas["IMDb Rating"] <= 8.6].tail(3)
# Out:
#                      IMDb Rating  Year Certificates   Genre  \
# Title
# Mother of the Bride          4.8  2024        TV-PG  Comedy
# The Idea of You              6.4  2024            R  Comedy
# The Fall Guy                 7.1  2024        PG-13  Action
#
#                               Director  \
# Title
# Mother of the Bride        Mark Waters
# The Idea of You      Michael Showalter
# The Fall Guy              David Leitch
#
#                                                         Star Cast  MetaScore  \
# Title
# Mother of the Bride  Brooke ShieldsMiranda CosgroveBenjamin Bratt       39.0
# The Idea of You         Anne HathawayNicholas GalitzineElla Rubin       67.0
# The Fall Guy          Ryan GoslingEmily BluntAaron Taylor-Johnson       73.0
#
#                      Duration (minutes) Clasificacion        revenue
# Title
# Mother of the Bride                88.0           NaN  Fracaso Total
# The Idea of You                   115.0           NaN  Fracaso Total
# ...

# %%
peliculas[peliculas["Year"] <2024].tail(3)
# Out:
#                  IMDb Rating  Year Certificates   Genre    Director  \
# Title
# Beetlejuice              7.5  1988           PG  Comedy  Tim Burton
# Laapataa Ladies          8.5  2023            R  Comedy   Kiran Rao
# Anyone But You           6.1  2023            R  Comedy  Will Gluck
#
#                                                      Star Cast  MetaScore  \
# Title
# Beetlejuice         Michael McDowellLarry WilsonWarren Skaaren       71.0
# Laapataa Ladies  Nitanshi GoelPratibha RantaSparsh Shrivastava       66.9
# Anyone But You                         Ilana WolpertWill Gluck       52.0
#
#                  Duration (minutes) Clasificacion        revenue
# Title
# Beetlejuice                    92.0           NaN  Fracaso Total
# Laapataa Ladies               116.3           NaN  Fracaso Total
# Anyone But You                103.0           NaN  Fracaso Total

# %%
peliculas[peliculas["MetaScore"] >= 8.0].head(3)
# Out:
#                                                IMDb Rating  Year Certificates  \
# Title
# Gladiator                                              8.5  2000            R
# Mission: Impossible - Dead Reckoning Part One          7.7  2023        PG-13
# Rebel Moon - Part Two: The Scargiver                   5.2  2024        PG-13
#
#                                                 Genre               Director  \
# Title
# Gladiator                                      Action           Ridley Scott
# Mission: Impossible - Dead Reckoning Part One  Action  Christopher McQuarrie
# Rebel Moon - Part Two: The Scargiver           Action            Zack Snyder
#
#                                                                                Star Cast  \
# Title
# Gladiator                                      David FranzoniJohn LoganWilliam Nicholson
# Mission: Impossible - Dead Reckoning Part One         Tom CruiseHayley AtwellVing Rhames
# ...

# %%
peliculas[peliculas["Year"] == 2016]
# Out:
#                                              IMDb Rating  Year Certificates  \
# Title
# Sing                                                 7.1  2016           PG
# Zootopia                                             8.0  2016           PG
# Your Name.                                           8.4  2016            R
# Moana                                                7.6  2016           PG
# Split                                                7.3  2016        PG-13
# Miss Peregrine's Home for Peculiar Children          6.7  2016        PG-13
# Deadpool                                             8.0  2016            R
#
#                                                  Genre            Director  \
# Title
# Sing                                         Animation      Garth Jennings
# Zootopia                                     Animation        Byron Howard
# Your Name.                                   Animation      Makoto Shinkai
# ...

# %%
from pymongo import MongoClient as mc

# %%
cliente = mc("mongodb://localhost:27017/")
db = cliente["midb"]
collection = db["agenda"]

# %%
data = {
    "nombre": ["Adrian","Josue","Carlos"],
    "edad": [20,20,20],
    "Direccion": ["Conocoto","Ciudadela Ibarra","Bicentenario"] 
}

# %%
df = pd.DataFrame(data)
data_dict= df.to_dict("records")
collection.insert_many(data_dict)

# %%
infoFortine = "Fortnite Statistics.csv"
df = pd.read_csv(infoFortine)
fort = db["Fornite"]
data_dict = df.to_dict("records")
fort.insert_many(data_dict)

# %%
info = list(fort.find())
DatosFornite = pd.DataFrame(info)
DatosFornite.head(10)
# Out:
#                         _id  Date Time of Day  Placed Mental State  \
# 0  673391eee6fb770e5033f9d8  4/10     6:00 PM      27        sober
# 1  673391eee6fb770e5033f9d9  4/10     6:00 PM      45        sober
# 2  673391eee6fb770e5033f9da  4/10     6:00 PM      38         high
# 3  673391eee6fb770e5033f9db  4/10     7:00 PM      30         high
# 4  673391eee6fb770e5033f9dc  4/10     7:00 PM      16         high
# 5  673391eee6fb770e5033f9dd  4/10     7:00 PM      30         high
# 6  673391eee6fb770e5033f9de  4/10     7:00 PM      20         high
# 7  673391eee6fb770e5033f9df  4/10     7:00 PM      29         high
# 8  673391eee6fb770e5033f9e0  4/10     7:00 PM      21         high
# 9  673391eee6fb770e5033f9e1  4/10     8:00 PM      24         high
#
#    Eliminations  Assists  Revives Accuracy  Hits  Head Shots  \
# 0             2        0        0      23%    14           2
# 1             1        2        0      30%    19           1
# ...

# %%
DatosFornite[DatosFornite["Accuracy"] <="10%"].head()
# Out:
#                          _id  Date Time of Day  Placed Mental State  \
# 5   673391eee6fb770e5033f9dd  4/10     7:00 PM      30         high
# 49  673391eee6fb770e5033fa09  4/14     1:00 PM      32        sober
# 73  673391eee6fb770e5033fa21  4/15     5:00 PM      15         high
#
#     Eliminations  Assists  Revives Accuracy  Hits  Head Shots  \
# 5              0        1        0      10%     3           1
# 49             0        0        0      10%     9           2
# 73             2        2        1      10%    13           4
#
#     Distance Traveled  Materials Gathered  Materials Used  Damage Taken  \
# 5              575.59                  78              60           146
# 49             411.05                 139              30           212
# 73             792.00                 118             110           313
#
#     Damage to Players  Damage to Structures
# 5                 117                  5482
# 49                276                  2090
# ...

# %%
DatosFornite[DatosFornite["Placed"] == 1].head(10)
# Out:
#                          _id  Date Time of Day  Placed Mental State  \
# 20  673391eee6fb770e5033f9ec  4/11     3:00 PM       1        sober
# 38  673391eee6fb770e5033f9fe  4/13     8:00 PM       1         high
# 74  673391eee6fb770e5033fa22  4/15     6:00 PM       1         high
#
#     Eliminations  Assists  Revives Accuracy  Hits  Head Shots  \
# 20             7        0        0      25%    63           9
# 38             6        3        1      17%    46           7
# 74             4        5        0      16%    35           3
#
#     Distance Traveled  Materials Gathered  Materials Used  Damage Taken  \
# 20             3320.0                 541             530           180
# 38             3830.0                1907             530           193
# 74             4460.0                 941             350           182
#
#     Damage to Players  Damage to Structures
# 20               1399                 17151
# 38               1308                 18026
# ...

# %%
DatosFornite[DatosFornite["Eliminations"] >= 8].head()
# Out:
#                          _id    Date Time of Day  Placed Mental State  \
# 30  673391eee6fb770e5033f9f6    4/13     2:00 PM       2        sober
# 82  673391eee6fb770e5033fa2a  17-Apr    12:00 AM       2         high
#
#     Eliminations  Assists  Revives Accuracy  Hits  Head Shots  \
# 30             8        0        1      17%    34           7
# 82             8        2        0      31%    97           8
#
#     Distance Traveled  Materials Gathered  Materials Used  Damage Taken  \
# 30             3790.0                3002            1740           321
# 82             3770.0                1750             400           576
#
#     Damage to Players  Damage to Structures
# 30               1166                 10594
# 82               1492                  4593
